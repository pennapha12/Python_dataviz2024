# %% [markdown]
# <a href="https://colab.research.google.com/github/pennapha12/Python_dataviz2024/blob/main/MTExam1_653020215_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
from scipy import stats

# %%
df=pd.read_excel('/content/drive/MyDrive/for_work/basic_python/Exam_1/test-TidyData_2024.xlsx')
df.head()
# Out:
#        month  station  rep.    Chlo_a    Chlo_b  total_Caro  Temp.    pH  \
# 0  July_2018        1     1  0.094645  0.011954    0.026780   30.2  5.54
# 1  July_2018        2     1  0.038433  0.059019    0.021387   29.1  6.24
# 2  July_2018        3     1  0.043884  0.089415    0.023223   29.7  5.52
# 3  July_2018        4     1  0.039836  0.064552    0.016537   29.2  5.92
# 4  July_2018        5     1  0.044712  0.062424    0.022990   29.5  5.79
#
#       EC  Salinity    TDS    DO   Nitrate  Ammonium  Phosphate  No.Algal_cell  \
# 0  622.7     330.3  545.2  4.37  0.172902  0.052817   0.012748   1.635833e+05
# 1  580.7     307.0  488.2  6.55  0.154197  0.144843   0.006086   1.166667e+06
# 2  547.1     289.4  462.2  5.67  0.153097  0.154321   0.014158   2.970000e+06
# 3  473.6     249.2  397.9  0.69  0.157026  0.387408   0.056951   5.066667e+05
# 4  685.5     366.0  581.2  4.46  0.204024  0.043387   0.007239   1.265000e+06
#
#    @dropdown
# 0        NaN
# 1        NaN
# 2        NaN
# ...

# %% [markdown]
# #ข้อ 1 ให้หา
# 1. ความแตกต่างของ ค่าเฉลี่ย ของข้อมูล Chlo_a ทุกๆ station ระหว่างปี 2018 และ ปี 2019

# %%
df['month_only'] = df['month'].str.split('_').str[0]
df['year'] = df['month'].str.split('_').str[1]

# %%
mean_chlo_a=df.groupby(['station','year'])['Chlo_a'].mean().unstack()
mean_chlo_a['diff']=mean_chlo_a['2018']-mean_chlo_a['2019']
mean_chlo_a
# Out:
# year         2018      2019      diff
# station
# 1        0.052529  0.018268  0.034261
# 2        0.048112  0.027911  0.020201
# 3        0.053285  0.023057  0.030228
# 4        0.046794  0.021620  0.025173
# 5        0.043432  0.020100  0.023331
# 6        0.043809  0.015594  0.028215

# %% [markdown]
# #ข้อ 2
# 2. สร้างตารางค่าเฉลี่ย Chlo_b ทุกๆ station ของแต่ละเดือน

# %%
mean_chlo_b = df.groupby(['month_only','station'])['Chlo_b'].mean().unstack()
mean_chlo_b
# Out:
# station            1         2         3         4         5         6
# month_only
# Apr         0.051381  0.019378  0.030775  0.020170  0.027015  0.025655
# Aug         0.075665  0.065403  0.065179  0.061289  0.060107  0.063027
# Dec         0.070061  0.064375  0.080867  0.061951  0.070085  0.065663
# Jan         0.022451  0.014968  0.017722  0.012142  0.009789  0.013856
# July        0.030526  0.038211  0.045500  0.035326  0.037839  0.033133
# June        0.020548  0.013194  0.013301  0.013821  0.013880  0.008583
# May         0.015949  0.028765  0.015890  0.015559  0.016623  0.023882
# Nov         0.075937  0.064552  0.097963  0.070605  0.063866  0.073360
# Oct         0.131764  0.122767  0.106404  0.090834  0.082381  0.079449
# Sep         0.063890  0.074578  0.076292  0.064670  0.060733  0.061750
