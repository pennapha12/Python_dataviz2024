# %% [markdown]
# <a href="https://colab.research.google.com/github/pennapha12/Python_dataviz2024/blob/main/MTExam_2_65302002158.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #สืบคดี
# จากตารางฐานข้อมูล ต่างๆต่อไปนี้
#
# https://drive.google.com/drive/folders/15z9pnjM2cJwLU2ewL_JFPc3LJhrDmcbV?usp=sharing
#
# ให้สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City โดยเริ่มจากการตรวจสอบ ข้อมูลคดี (crime_scene_report.csv)
#
# หมายเหตุ
# person.csv ข้อมูลประชากร
#
# interview.csv ข้อมูลการสอบสวน
#
# income.csv ข้อมูลรายได้
#
# get_fit_now_member.csv ข้อมูลสมาชิก ฟิตเนส Get Fit Now
#
# get_fit_now_check_in.csv ข้อมูลการเข้าใช้ ฟิตเนส Get Fit Now
#
# facebook_event_checkin.csv ข้อมูลการเช็คอิน Facebook
#
# driver_license.csv ข้อมูลใบขับขี่
#
# crime_scene_report.csv ข้อมูลคดี

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
import os
path = '/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2'

# %%
per_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/person.csv')
interview_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/interview.csv')
income_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/income.csv')
member_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/get_fit_now_member.csv')
check_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/get_fit_now_check_in.csv')
facebook_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/facebook_event_checkin.csv')
driver_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/drivers_license.csv')
crime_path= os.path.join(path,'/content/drive/MyDrive/for_work/basic_python/Exam_2_653020215-8/Exam_2/crime_scene_report.csv')

# %%
#data
person=pd.read_csv(per_path)
interview=pd.read_csv(interview_path)
income=pd.read_csv(income_path)
member=pd.read_csv(member_path)
check=pd.read_csv(check_path)
facebook=pd.read_csv(facebook_path)
driver=pd.read_csv(driver_path)
crime=pd.read_csv(crime_path)

# %% [markdown]
# #ตรวจสอบข้อมูลคดี

# %%
crime.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
# แปลงคอลัมน์ 'date' เป็น datetime
crime['date'] = pd.to_datetime(crime['date'], format='%Y%m%d', errors='coerce')
crime.head()
# Out:
#         date     type                                        description  \
# 0 2018-01-15  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1 2018-01-15   murder                  Life? Dont talk to me about life.
# 2 2018-01-15   murder  Mama, I killed a man, put a gun against his he...
# 3 2018-02-15   murder                         REDACTED REDACTED REDACTED
# 4 2018-02-15   murder  Someone killed the guard! He took an arrow to ...
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
#ค้นหาคดีในวันที่ 15 มค 2018 ในเมือง  SQL city
crime[
      (crime['city']=='SQL City')&
      (crime['date']=='20180115')&
      (crime['type']=='murder')
      ]
# Out:
#            date    type                                        description  \
# 1227 2018-01-15  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %%
#"ภาพจากกล้องวงจรปิดแสดงให้เห็นว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน 'Northwestern Dr' ส่วนพยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ใดที่หนึ่งบนถนน 'Franklin Ave'"

# %% [markdown]
# #ตรวจสอบคดี

# %%
person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %% [markdown]
# #หาข้อมูลพยาน

# %%
person[person['address_street_name']=='Northwestern Dr'].sort_values(by='address_number',ascending=False).head(1)
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %%
interview[interview['person_id']==14887]
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...

# %%
'''
"ฉันได้ยินเสียงปืนแล้วยังเห็นผู้ชายคนหนึ่งวิ่งออกมา เขามีกระเป๋าที่มาจากยิม 'Get Fit Now Gym'
หมายเลขสมาชิกบนกระเป๋าเริ่มต้นด้วย '48Z' มีแต่สมาชิกระดับทองเท่านั้นที่มีกระเป๋าแบบนั้น ชายคนนั้นขึ้นรถที่มีป้ายทะเบียนซึ่งมีตัวอักษร 'H42W' รวมอยู่ด้วย"
'''

# %%
person[
    (person['address_street_name']=='Franklin Ave')&
    (person['name']=='Annabel Miller')
    ]
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
interview[interview['person_id']==16371]
# Out:
#       person_id                                         transcript
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
'''
"ฉันเห็นเหตุการณ์ฆาตกรรมเกิดขึ้น และฉันจำคนร้ายได้ เพราะเคยเห็นเขาที่โรงยิมของฉันเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม"
'''

check.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time       date
# 0         NL318       20180212            329             365 2018-02-12
# 1         NL318       20170811            469             920 2017-08-11
# 2         NL318       20180429            506             554 2018-04-29
# 3         NL318       20180128            124             759 2018-01-28
# 4         NL318       20171027            418            1019 2017-10-27

# %%
member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
check[check['date']=='2018-01-09']
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time       date
# 113          X0643       20180109            957            1164 2018-01-09
# 889          UK1F2       20180109            344             518 2018-01-09
# 1329         XTE42       20180109            486            1124 2018-01-09
# 1446         1AE2H       20180109            461             944 2018-01-09
# 1703         6LSTG       20180109            399             515 2018-01-09
# 2137         7MWHJ       20180109            273             885 2018-01-09
# 2435         GE5Q8       20180109            367             959 2018-01-09
# 2700         48Z7A       20180109           1600            1730 2018-01-09
# 2701         48Z55       20180109           1530            1700 2018-01-09
# 2702         90081       20180109           1600            1700 2018-01-09

# %%
check.columns
# Out:
# Index(['membership_id', 'check_in_date', 'check_in_time', 'check_out_time',
#        'date'],
#       dtype='object')

# %%
member.columns
# Out:
# Index(['id', 'person_id', 'name', 'membership_start_date',
#        'membership_status'],
#       dtype='object')

# %%
member = member.rename(columns={'id': 'membership_id'})

# %%
member9=member.merge(check,on='membership_id',how='inner')
member9.head()
# Out:
#   membership_id  person_id             name  membership_start_date  \
# 0         NL318      65076  Everette Koepke               20170926
# 1         NL318      65076  Everette Koepke               20170926
# 2         NL318      65076  Everette Koepke               20170926
# 3         NL318      65076  Everette Koepke               20170926
# 4         NL318      65076  Everette Koepke               20170926
#
#   membership_status  check_in_date  check_in_time  check_out_time       date
# 0              gold       20180212            329             365 2018-02-12
# 1              gold       20170811            469             920 2017-08-11
# 2              gold       20180429            506             554 2018-04-29
# 3              gold       20180128            124             759 2018-01-28
# 4              gold       20171027            418            1019 2017-10-27

# %%
df=member9[member9['date']=='2018-01-09']
df
# Out:
#      membership_id  person_id               name  membership_start_date  \
# 113          X0643      15247     Shondra Ledlow               20170521
# 889          UK1F2      28073   Zackary Cabotage               20170818
# 1329         XTE42      55662     Sarita Bartosh               20170524
# 1446         1AE2H      10815   Adriane Pelligra               20170816
# 1703         6LSTG      83186      Burton Grippe               20170214
# 2137         7MWHJ      31523  Blossom Crescenzo               20180309
# 2435         GE5Q8      92736      Carmen Dimick               20170618
# 2700         48Z7A      28819       Joe Germuska               20160305
# 2701         48Z55      67318      Jeremy Bowers               20160101
# 2702         90081      16371     Annabel Miller               20160208
#
#      membership_status  check_in_date  check_in_time  check_out_time  \
# 113             silver       20180109            957            1164
# ...

# %%
# กรองข้อมูลโดยใช้ค่า memb
filtered_person = df[df['membership_id'].isin(['48Z7A', '48Z55'])]
filtered_person
# Out:
#      membership_id  person_id           name  membership_start_date  \
# 2700         48Z7A      28819   Joe Germuska               20160305
# 2701         48Z55      67318  Jeremy Bowers               20160101
#
#      membership_status  check_in_date  check_in_time  check_out_time  \
# 2700              gold       20180109           1600            1730
# 2701              gold       20180109           1530            1700
#
#            date
# 2700 2018-01-09
# 2701 2018-01-09

# %%
driver.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
driver[driver['plate_number'].str.contains('H42W')]
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
person[person['license_id']==423327]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %%
person[person['license_id']==183779]
# Out:
#          id            name  license_id  address_number address_street_name  \
# 7578  78193  Maxine Whitely      183779             110             Fisk Rd
#
#             ssn
# 7578  137882671

# %%
person[person['license_id']==664760]
# Out:
#          id            name  license_id  address_number address_street_name  \
# 4664  51739  Tushar Chandra      664760             312              Phi St
#
#             ssn
# 4664  137882671

# %%
interview.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
interview[interview['person_id']==67318]

'''
"ฉันถูกว่าจ้างโดยผู้หญิงคนหนึ่งที่มีเงินมาก ฉันไม่รู้ชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
เธอมีผมสีแดงและขับรถ Tesla Model S ฉันรู้ว่าเธอเคยเข้าร่วมคอนเสิร์ต SQL Symphony ถึง 3 ครั้งในเดือนธันวาคม 2017"
'''
# Out:
#       person_id                                        description
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %%
interview[interview['person_id']==78193]
# Out:
# Empty DataFrame
# Columns: [person_id, description]
# Index: []

# %%
interview[interview['person_id']==664760]
# Out:
# Empty DataFrame
# Columns: [person_id, description]
# Index: []

# %%
facebook.head()
# Out:
#    person_id  event_id                                         event_name  \
# 0      28508      5880    Nudists are people who wear one-button suits.\n
# 1      63713      3865  but that's because it's the best book on anyth...
# 2      63713      3999           If Murphy's Law can go wrong, it will.\n
# 3      63713      6436  Old programmers never die.  They just branch t...
# 4      82998      4470               Help a swallow land at Capistrano.\n
#
#         date
# 0 2017-09-13
# 1 2017-10-09
# 2 2017-05-02
# 3 2017-09-26
# 4 2017-10-22

# %%
event_counts =facebook[
    (facebook['event_name'] == 'SQL Symphony Concert') &
    (facebook['date'] >= '2017-12-01') &
    (facebook['date'] <= '2017-12-31')].groupby('person_id').size()
event_counts.sort_values(ascending=False)
# Out:
# person_id
# 24556    3
# 99716    3
# 28582    2
# 11173    1
# 19260    1
# 19292    1
# 24397    1
# 43366    1
# 58898    1
# 62596    1
# 67318    1
# 69325    1
# 69699    1
# 79312    1
# 81526    1
# 92343    1
# dtype: int64

# %%
person[person['id']==24556]
# Out:
#          id         name  license_id  address_number address_street_name  \
# 1587  24556  Bryan Pardo      101191             703          Machine Ln
#
#             ssn
# 1587  816663882

# %%
person[person['id']==99716]
# Out:
#          id              name  license_id  address_number address_street_name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 9985  987756388

# %%
driver.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
driver[driver['id']==10191]
# Out:
# Empty DataFrame
# Columns: [id, age, height, eye_color, hair_color, gender, plate_number, car_make, car_model]
# Index: []

# %%
driver[driver['id']==202298]
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
#
#      car_model
# 1105   Model S

# %%
income.head()
# Out:
#          ssn  annual_income
# 0  100009868          52200
# 1  100169584          64500
# 2  100300433          74400
# 3  100355733          35900
# 4  100366269          73000

# %%
income[income['ssn']==987756388]
# Out:
#             ssn  annual_income
# 7422  987756388         310000

# %% [markdown]
# # สรุปให้ตัวเองค่ะ
#
# ##ข้อมูลคดี
#
# "ภาพจากกล้องวงจรปิดแสดงให้เห็นว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน 'Northwestern Dr' ส่วนพยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ใดที่หนึ่งบนถนน 'Franklin Ave'"
#
# ##รวมคำให้การของพยานทั้ง 2 คน
# ###คนที่ 1
#
# '''
# "ฉันได้ยินเสียงปืนแล้วยังเห็นผู้ชายคนหนึ่งวิ่งออกมา เขามีกระเป๋าที่มาจากยิม 'Get Fit Now Gym'
# หมายเลขสมาชิกบนกระเป๋าเริ่มต้นด้วย '48Z' มีแต่สมาชิกระดับทองเท่านั้นที่มีกระเป๋าแบบนั้น ชายคนนั้นขึ้นรถที่มีป้ายทะเบียนซึ่งมีตัวอักษร 'H42W' รวมอยู่ด้วย"
# '''
#
# ###คนที่ 2
#
# '''
# "ฉันเห็นเหตุการณ์ฆาตกรรมเกิดขึ้น และฉันจำคนร้ายได้ เพราะเคยเห็นเขาที่โรงยิมของฉันเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม"
# '''
#
# ##ขั้นตอนการหา
# 1. หาข้อมูลพยานจาก Crime
#
# 2. จากพยานคนที่ 2 นำไปหาว่าในวันที่ 9 มกราคม 2018 ใครเข้าใช้ยิมบ้าง จาก check
#
# 3. จากพยานคนที่ 1 ว่าสมาชิกคนเข้าใช้งานวันที่ 9 และมีขึ้นต้นด้วย '48Z' จากการเอา check marge member
#
# 4. นำข้อมูลทั้ง 2 คน ไปหาว่าเข้าขึ้นรถคันไหนไป จากพยานคนที่ 1 ที่บอกว่าเขาขึ้นรถที่ป้ายทะเบียนมี 'H42W' รวมอยู่
#
# 5. นำข้อมูลไปหาว่ามีใครให้การบ้าง
#
# ####คำให้การ
# '''
# "ฉันถูกว่าจ้างโดยผู้หญิงคนหนึ่งที่มีเงินมาก ฉันไม่รู้ชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
# เธอมีผมสีแดงและขับรถ Tesla Model S ฉันรู้ว่าเธอเคยเข้าร่วมคอนเสิร์ต SQL Symphony ถึง 3 ครั้งในเดือนธันวาคม 2017"
# '''
#
# ุ6. นำคำให้การไปสืบคดีต่อ เริ่มจากหาว่าใครเช็คอินคอนเสิร์ต SQL Symphony ถึง 3 ครั้งในเดือนธันวาคม 2017 จาก facebook
#
# 7. นำข้อมูลที่ได้ไปสืบหาต่อใน driver และ income
